# %%
from sklearn.cluster import KMeans
import pandas as pd 
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv('employee_data.csv')
df=df.head(1000)
df
# Out:
#      Unnamed: 0   id groups  age  healthy_eating  active_lifestyle  salary
# 0             0    0      A   36               5                 5    2297
# 1             1    1      A   55               3                 5    1134
# 2             2    2      A   61               8                 1    4969
# 3             3    3      O   29               3                 6     902
# 4             4    4      O   34               6                 2    3574
# ..          ...  ...    ...  ...             ...               ...     ...
# 995         995  995      O   33               7                 7    2996
# 996         996  996      O   21               1                 2     667
# 997         997  997      O   49               9                 7    4158
# 998         998  998     AB   56               6                 7    2414
# 999         999  999      B   64               4                 9     788
#
# [1000 rows x 7 columns]

# %%
plt.scatter(df.age,df.salary)

# %%
km = KMeans(n_clusters=3)
km
# Out:
# KMeans(n_clusters=3)

# %%
ypredectid=km.fit_predict(df[['age','salary']])
ypredectid
# Out:
# array([1, 2, 0, 2, 0, 1, 2, 0, 1, 2, 1, 0, 1, 1, 0, 2, 2, 2, 2, 0, 0, 2,
#        0, 1, 2, 1, 0, 2, 1, 0, 2, 1, 2, 2, 1, 2, 1, 2, 2, 2, 1, 1, 1, 2,
#        1, 2, 1, 2, 1, 1, 2, 2, 0, 2, 2, 1, 1, 0, 0, 0, 1, 2, 1, 1, 0, 1,
#        2, 0, 1, 0, 1, 1, 0, 1, 1, 0, 2, 1, 1, 1, 1, 1, 1, 0, 2, 0, 1, 1,
#        1, 2, 1, 2, 0, 0, 2, 2, 0, 1, 1, 2, 2, 1, 2, 2, 1, 0, 1, 1, 1, 2,
#        2, 1, 1, 2, 0, 2, 1, 2, 2, 1, 1, 0, 0, 1, 2, 2, 2, 0, 2, 1, 1, 1,
#        2, 1, 1, 2, 1, 2, 2, 1, 1, 1, 1, 2, 2, 1, 0, 0, 1, 1, 1, 2, 0, 1,
#        2, 1, 1, 0, 1, 0, 2, 2, 0, 0, 2, 0, 1, 2, 0, 1, 1, 2, 2, 0, 2, 2,
#        1, 2, 2, 1, 2, 1, 0, 2, 1, 0, 1, 2, 0, 2, 1, 0, 2, 2, 2, 1, 2, 0,
#        2, 1, 2, 1, 1, 0, 1, 2, 0, 0, 0, 1, 2, 0, 0, 1, 1, 0, 2, 2, 2, 2,
#        1, 1, 2, 0, 1, 2, 2, 1, 0, 1, 2, 1, 2, 2, 1, 2, 1, 1, 2, 0, 1, 2,
#        1, 2, 2, 1, 2, 2, 1, 2, 1, 0, 1, 2, 2, 0, 2, 0, 0, 1, 1, 2, 2, 2,
#        1, 1, 0, 1, 2, 0, 0, 2, 1, 0, 0, 0, 2, 1, 2, 2, 1, 1, 0, 0, 2, 1,
# ...

# %%
df['cluster']= ypredectid
df.head()
# Out:
#    Unnamed: 0  id groups  age  healthy_eating  active_lifestyle  salary  \
# 0           0   0      A   36               5                 5    2297
# 1           1   1      A   55               3                 5    1134
# 2           2   2      A   61               8                 1    4969
# 3           3   3      O   29               3                 6     902
# 4           4   4      O   34               6                 2    3574
#
#    cluster
# 0        1
# 1        2
# 2        0
# 3        2
# 4        0

# %%
df1=df[df.cluster==0]
df2=df[df.cluster==1]
df3=df[df.cluster==2]

df3
# Out:
#      Unnamed: 0   id groups  age  healthy_eating  active_lifestyle  salary  \
# 1             1    1      A   55               3                 5    1134
# 3             3    3      O   29               3                 6     902
# 6             6    6     AB   53               4                 6    1484
# 9             9    9      A   31               4                 8    1020
# 15           15   15      B   57               3                 8     662
# ..          ...  ...    ...  ...             ...               ...     ...
# 988         988  988      O   60               4                 6    1484
# 989         989  989      O   44               3                 5    1134
# 990         990  990     AB   20               3                 4    1366
# 996         996  996      O   21               1                 2     667
# 999         999  999      B   64               4                 9     788
#
#      cluster
# 1          2
# 3          2
# 6          2
# ...

# %%
plt.scatter(df1.age,df1.salary,color='green')
plt.scatter(df2.age,df2.salary,color='red')
plt.scatter(df3.age,df3.salary,color = 'blue')

plt.xlabel('age')
plt.ylabel('salary ($)')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sclaer = MinMaxScaler()
sclaer.fit(df[['salary']])
df['salary']=sclaer.transform(df[['salary']])
df
# Out:
#      Unnamed: 0   id groups  age  healthy_eating  active_lifestyle    salary  \
# 0             0    0      A   36               5                 5  0.349009
# 1             1    1      A   55               3                 5  0.116270
# 2             2    2      A   61               8                 1  0.883730
# 3             3    3      O   29               3                 6  0.069842
# 4             4    4      O   34               6                 2  0.604563
# ..          ...  ...    ...  ...             ...               ...       ...
# 995         995  995      O   33               7                 7  0.488893
# 996         996  996      O   21               1                 2  0.022814
# 997         997  997      O   49               9                 7  0.721433
# 998         998  998     AB   56               6                 7  0.372423
# 999         999  999      B   64               4                 9  0.047028
#
#      cluster
# 0          1
# 1          2
# ...

# %%
sclaer.fit(df[['age']])
df['age']=sclaer.transform(df[['age']])
df
# Out:
#      Unnamed: 0   id groups       age  healthy_eating  active_lifestyle  \
# 0             0    0      A  0.391304               5                 5
# 1             1    1      A  0.804348               3                 5
# 2             2    2      A  0.934783               8                 1
# 3             3    3      O  0.239130               3                 6
# 4             4    4      O  0.347826               6                 2
# ..          ...  ...    ...       ...             ...               ...
# 995         995  995      O  0.326087               7                 7
# 996         996  996      O  0.065217               1                 2
# 997         997  997      O  0.673913               9                 7
# 998         998  998     AB  0.826087               6                 7
# 999         999  999      B  1.000000               4                 9
#
#        salary  cluster
# 0    0.349009        1
# 1    0.116270        2
# 2    0.883730        0
# ...

# %%
km = KMeans(n_clusters=3)
ypredectid=km.fit_predict(df[['age','salary']])

df['cluster']= ypredectid
# df.drop(['id','groups'],axis='columns',inplace=True)
df
# Out:
#      Unnamed: 0   id groups       age  healthy_eating  active_lifestyle  \
# 0             0    0      A  0.391304               5                 5
# 1             1    1      A  0.804348               3                 5
# 2             2    2      A  0.934783               8                 1
# 3             3    3      O  0.239130               3                 6
# 4             4    4      O  0.347826               6                 2
# ..          ...  ...    ...       ...             ...               ...
# 995         995  995      O  0.326087               7                 7
# 996         996  996      O  0.065217               1                 2
# 997         997  997      O  0.673913               9                 7
# 998         998  998     AB  0.826087               6                 7
# 999         999  999      B  1.000000               4                 9
#
#        salary  cluster
# 0    0.349009        2
# 1    0.116270        1
# 2    0.883730        1
# ...

# %%
df1=df[df.cluster==0]
df2=df[df.cluster==1]
df3=df[df.cluster==2]

df3

plt.scatter(df1.age,df1.salary,color='green')
plt.scatter(df2.age,df2.salary,color='red')
plt.scatter(df3.age,df3.salary,color = 'blue')

plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color='orange',marker = '*',label='centroid')

plt.xlabel('age')
plt.ylabel('salary ($)')
plt.legend()

# %%
km.cluster_centers_
# Out:
# array([[0.31530649, 0.58372154],
#        [0.77645248, 0.29698793],
#        [0.24828375, 0.19219295]])

# %%
k_range=range(1,10)
sse = []
for k in k_range:
    km = KMeans(n_clusters=k)
    km.fit(df[['age','salary']])
    sse.append(km.inertia_)

# %%
sse
# Out:
# [132.25574866164274,
#  67.53697174121046,
#  48.196647184793605,
#  35.13869632735892,
#  27.957325281807503,
#  23.62412321020304,
#  20.425866166198418,
#  17.71162667379903,
#  15.343403742714107]

# %%
plt.xlabel('K')
plt.ylabel('Sum of suaroid error')
plt.plot(k_range,sse)
